# %% [markdown]
# # Part C: Implementation
#
# **Author:** Martín Gottschalk
# **Date:** 2026-03-23
#
# This notebook contains the implementation for Certamen 1 of the AI Workshop.

# %% [markdown]
# ## Setup
#
# Import required libraries and configure the environment.

# %%
# Import libraries
import os

# %% [markdown]
# ## Implementation
#
# _Add implementation steps here._

# %%
# Implementation code goes here

# %% [markdown]
# ## Results
#
# _Present and discuss the results._

# %%
# Results and evaluation code goes here

# %% [markdown]
# ## Conclusions
#
# _Summarize the conclusions drawn from the implementation._
